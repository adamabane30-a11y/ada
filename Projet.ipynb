# %% [markdown]
# <a href="https://colab.research.google.com/github/adamabane30-a11y/ada/blob/main/Projet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def afficher_menu():
    """
    Affiche les options disponibles pour l'utilisateur.
    """
    print("\n ")
    print("      GESTION POINT DE VENTE      ")
    print("1. Ajouter un produit au catalogue")
    print("2. Afficher le catalogue")
    print("3. Enregistrer une vente")
    print("4. Rechercher un produit (Bonus)")
    print("5. Afficher les statistiques")
    print("6. Quitter le programme")

def main():
    """
    Boucle principale gérée par l'Étudiant A.
    Elle appelle les fonctions développées par le reste du groupe.
    """
    while True:
        afficher_menu()
        choix = input("Entrez votre choix (1-6) : ").strip()
        if choix == "1":
            ajouter_produit()
        elif choix == "2":
            afficher_catalogue()
        elif choix == "3":
            enregistrer_vente()
        elif choix == "4":
            rechercher_produit()
        elif choix == "5":
            afficher_statistiques()
        elif choix == "6":
            print("\n Sauvegarde des données en cours...")
            sauvegarder_ventes()
            print("Au revoir ! Merci d'avoir utilisé notre application.")
            break
        else:
            print("Choix invalide ! Veuillez saisir un nombre entre 1 et 6.")
